# %%
# importing the required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from IPython.display import display
import re

warnings.filterwarnings('ignore')
pd.set_option("display.max_rows",500)
pd.set_option("display.max_columns",500)
pd.set_option('display.max_colwidth', None)

# %%
# loading the data
df = pd.read_csv("data/customer_data_RFM_features.csv",parse_dates=['DateTime'])

# %%
# printing the first 5 rows
df.head(5)
# Out:
#        User_id             Session_id            DateTime  \
# 0  52243841613  d76fde-8bb3-4e00-8c23 2019-01-10 10:20:00
# 1  52243841613  33dfbd-b87a-4708-9857 2019-01-10 10:22:00
# 2  57314161118  6511c2-e2e3-422b-b695 2019-01-10 14:00:00
# 3  57314161118  90fc70-0e80-4590-96f3 2019-01-10 14:07:00
# 4  57314161118  bd7419-2748-4c56-95b4 2019-01-10 14:12:00
#
#                 Category SubCategory          Action  Quantity  Rate  \
# 0  Electronic Appliances    Speakers  first_app_open       0.0   0.0
# 1  Electronic Appliances    Speakers          search       0.0   0.0
# 2          Men's Fashion       Jeans          search       0.0   0.0
# 3          Men's Fashion       Jeans    product_view       0.0   0.0
# 4          Men's Fashion       Jeans    read_reviews       0.0   0.0
#
#    Total Price  Recency  Frequency  Monetary   R   F   M  Group  Score Loyalty
# 0          0.0      NaN        NaN       NaN NaN NaN NaN    NaN    NaN     NaN
# 1          0.0      NaN        NaN       NaN NaN NaN NaN    NaN    NaN     NaN
# 2          0.0      NaN        NaN       NaN NaN NaN NaN    NaN    NaN     NaN
# 3          0.0      NaN        NaN       NaN NaN NaN NaN    NaN    NaN     NaN
# 4          0.0      NaN        NaN       NaN NaN NaN NaN    NaN    NaN     NaN

# %%
# checking the data shape
print(f"The shape of the dataframe is {df.shape}")
# Out:
# The shape of the dataframe is (2090, 18)

# %%
# basic check about the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2090 entries, 0 to 2089
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   User_id      2090 non-null   int64
#  1   Session_id   2090 non-null   object
#  2   DateTime     2090 non-null   datetime64[ns]
#  3   Category     2090 non-null   object
#  4   SubCategory  2090 non-null   object
#  5   Action       2090 non-null   object
#  6   Quantity     2090 non-null   float64
#  7   Rate         2090 non-null   float64
#  8   Total Price  2090 non-null   float64
#  9   Recency      1303 non-null   float64
#  10  Frequency    1303 non-null   float64
#  11  Monetary     1303 non-null   float64
#  12  R            1303 non-null   float64
#  13  F            1303 non-null   float64
#  14  M            1303 non-null   float64
#  15  Group        1303 non-null   float64
#  16  Score        1303 non-null   float64
#  17  Loyalty      1303 non-null   object
# dtypes: datetime64[ns](1), float64(11), int64(1), object(5)
# memory usage: 294.0+ KB

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# #### Date Level Features

# %%
# creating date level features like date, day_of_week, day_of_month
df['Date'] = df['DateTime'].dt.date
df['DayOfWeek'] = df['DateTime'].dt.dayofweek
df['DayOfMonth'] = df['DateTime'].dt.day

# %% [markdown]
# #### User activity features

# %% [markdown]
# ##### 1.No of Days Active

# %%
# creating a feature that says how many days the user were active on our platform
days_active = df.groupby('User_id').agg({'Date':'nunique'}).reset_index()
days_active.rename(columns={"Date":"days_active"},inplace=True)

days_active.head()
# Out:
#        User_id  days_active
# 0  51443820326            1
# 1  51448162784            3
# 2  51455512201            3
# 3  51462598385            5
# 4  51463622150            3

# %% [markdown]
# ##### 2. Avg time between purchases

# %%
# function to remove NaN from the list
def compute_avg_purchase_gap(lst):
    assert type(lst)==list
    if len(lst)==1:
        return np.nan
    # removing the NaN values
    lst_new = list(filter(lambda x: not pd.isna(x), lst))
    # returning the avg of the list (since we want avg purchase gap)
    return sum(lst_new)/len(lst_new)


# definin a function which gets avg time between purchases
def get_avg_time_between_purchases(data,action="Action",user_id="User_id",date_time="DateTime"):
    """ 
    data      : dataframe
    action    : name of the action column in the dataframe
    user_id   : name of the user_id column in the dataframe
    date_time : datetime of the action
    """
   # creating a copy of the dataframe
    dff = data.copy()
    # filtering the rows with only purchases
    purchases = dff[dff[action]=="purchase"]
    # selecting only the user id and datetime column
    purchases = purchases[[user_id,date_time]]
    # sorting the purchases by user_id and dattime
    purchases.sort_values(by=[user_id,date_time],ascending=[True,True],inplace=True)
    # creating a purchases_duration column
    purchases.head(2)
    # creating a purchases_duration column
    purchases['Purchase Gap'] = purchases.groupby([user_id])[date_time].diff().dt.total_seconds()
    # converting the timegap to days
    purchases['Purchase Gap'] = np.round(purchases['Purchase Gap']/(3600*24),0)
    # grouping the multiple purchase gaps for an user into a single list (if a cusomter does only single purchase then purchase gap would be NaN, if a person does two purchase then the list contains [nan,purchasegap])
    purchases = pd.DataFrame(purchases.groupby(user_id)["Purchase Gap"].apply(list)).reset_index()
    # applying the compute_avg_purchase_gap func
    purchases["Avg Purchase Gap"] = purchases["Purchase Gap"].apply(compute_avg_purchase_gap)
    
    return purchases

# %%
# computing the avg time between purchases for each user
avg_purchase_time = get_avg_time_between_purchases(df,"Action","User_id","DateTime")
avg_purchase_time.head()
# Out:
#        User_id  Purchase Gap  Avg Purchase Gap
# 0  51448162784  [nan, 184.0]             184.0
# 1  51455512201         [nan]               NaN
# 2  51462598385   [nan, 56.0]              56.0
# 3  51463622150   [nan, 29.0]              29.0
# 4  51465529647    [nan, 7.0]               7.0

# %% [markdown]
# ##### 3. Cart to purchase ratio

# %%
def get_ratios(data,level,action_col,action1,action2):
    """
    data       : name of the dataframe
    level      : the level in which we want to calculate ratios (if we want it in userlevel pass 'user_id column') (if we want it in category level pass category )
    action_col : name of the col that contains the actions
    action1    : action of interest 1
    action2    : action of interest 2 purchase

    this fuctino returns ratios of action1:action2
    """
    dff = data.copy()
    # creating a dataframe which has no of action1 done by each users
    col1 = dff.groupby(level)[action_col].value_counts().loc[:, action1].reset_index()
    # creating a dataframe which has no of action1 done by each users
    col2 = dff.groupby(level)[action_col].value_counts().loc[:, action2].reset_index()
    # combining both dfs
    ratios = pd.merge(col1, col2, on=level, how="left", suffixes=("_"+action1,"_"+action2) )
    # creating the ratio column which contains the action2/action1 value                 
    ratios[f'{action1}_to_{action2}_ratios']=ratios[f"count_{action2}"]/ratios[f"count_{action1}"]
    # filling NaNs with 0
    ratios.fillna(0,inplace=True)
    
    return ratios

# %%
# creating cart_purchase ratio for each user
cart_to_purchase = get_ratios(df,"User_id",'Action',"add_to_cart","purchase")
cart_to_purchase.head()
# Out:
#        User_id  count_add_to_cart  count_purchase  \
# 0  51448162784                  2             2.0
# 1  51455512201                  1             1.0
# 2  51462598385                  2             2.0
# 3  51463622150                  2             2.0
# 4  51465529647                  3             2.0
#
#    add_to_cart_to_purchase_ratios
# 0                        1.000000
# 1                        1.000000
# 2                        1.000000
# 3                        1.000000
# 4                        0.666667

# %% [markdown]
# ##### 4. Wishlist to purchase ratio

# %%
# creating wish_list_to_purchase ratio for each user
wishlist_to_purchase = get_ratios(df,"User_id",'Action',"add_to_wishlist","purchase")
wishlist_to_purchase.head()
# Out:
#        User_id  count_add_to_wishlist  count_purchase  \
# 0  51463622150                      1             2.0
# 1  51477448981                      2             1.0
# 2  51517997197                      2             2.0
# 3  51526464449                      1             2.0
# 4  51565158157                      4             3.0
#
#    add_to_wishlist_to_purchase_ratios
# 0                                2.00
# 1                                0.50
# 2                                1.00
# 3                                2.00
# 4                                0.75

# %%
# creating wish_list_click_to_purchase ratio for each user
wishlist_click_to_purchase = get_ratios(df,"User_id",'Action',"click_wishlist_page","purchase")
wishlist_click_to_purchase.head()
# Out:
#        User_id  count_click_wishlist_page  count_purchase  \
# 0  51448162784                          1             2.0
# 1  51463622150                          1             2.0
# 2  51465529647                          1             2.0
# 3  51468519074                          1             1.0
# 4  51475146821                          1             0.0
#
#    click_wishlist_page_to_purchase_ratios
# 0                                     2.0
# 1                                     2.0
# 2                                     2.0
# 3                                     1.0
# 4                                     0.0

# %%
df.Action.unique()
# Out:
# array(['first_app_open', 'search', 'product_view', 'read_reviews',
#        'add_review', 'add_to_cart', 'checkout', 'purchase',
#        'add_to_wishlist', 'click_wishlist_page', 'product_review'],
#       dtype=object)

# %% [markdown]
# ##### 5. Paths

# %%
# defining a function to get the latest path of each user
def get_paths(data,date_time,user_id,action_col):
    """
    data       : name of the dataframe
    user_id    : name of the col that contains the userid
    action_col : name of the col that contains the actions
    
    this fuctino returns the latest path of each user
    """
    
    # creating a temp copy 
    temp = data.copy()
    
    # sorting the temp df by datetime column in ascending order
    temp.sort_values(by=date_time,ascending=True)
    
    # filtering the rows with add_to_carts action
    add_to_carts = temp[temp[action_col]=="add_to_cart"] 
    
    # finding the last add_to_cart event for each user
    latest_add_to_carts = add_to_carts.groupby(user_id)[date_time].max()
    
    # filtering the rows with actions that was done before the last add to cart action of each user
    temp = temp[temp.DateTime<=temp[user_id].map(latest_add_to_carts)] # now this dataframe consists of actions before the last addtocart event for each users
    
    # picking the last three actions done before add_to_cart by each users
    paths = temp.groupby(user_id)[action_col].apply(list).reset_index(name='Actions_list')
    
    # Joining all the elements of the lists
    paths['Actions_list'] = paths['Actions_list'].apply(lambda x: ' '.join(x))
    
    # applying regex to find the last 3 actions 
    last_3_actions = r'((?:\S+\s+){0,3}\badd_to_cart)'
    paths["Last_3_Actions"] = paths['Actions_list'].apply(lambda x: re.findall(last_3_actions,x))
    
    # getting the latest path of the user
    paths["user_path"] = paths["Last_3_Actions"].apply(lambda x:x[-1])
    paths["user_path"] = paths["user_path"].apply(lambda x:"-->".join(x.split()))
    
    # dropping the unwanted columns
    paths = paths[[user_id,"user_path"]]

    return paths

# %%
# getting the paths for each users
paths = get_paths(df,"DateTime","User_id","Action")
paths.head()
# Out:
#        User_id                                           user_path
# 0  51448162784                 search-->read_reviews-->add_to_cart
# 1  51455512201  search-->product_view-->read_reviews-->add_to_cart
# 2  51462598385  search-->product_view-->read_reviews-->add_to_cart
# 3  51463622150      purchase-->search-->product_view-->add_to_cart
# 4  51465529647                                search-->add_to_cart

# %%
print(f"There are {paths['user_path'].nunique()} no unique path in which people are adding the product to the cart\n")
# Out:
# There are 44 no unique path in which people are adding the product to the cart

# %%
paths['user_path'].value_counts(ascending=True).head()
# Out:
# user_path
# add_to_wishlist-->search-->product_view-->add_to_cart           1
# search-->click_wishlist_page-->add_to_cart                      1
# add_to_wishlist-->click_wishlist_page-->search-->add_to_cart    1
# product_view-->search-->product_view-->add_to_cart              1
# checkout-->search-->product_view-->add_to_cart                  1
# Name: count, dtype: int64

# %% [markdown]
# as you can see lot of paths are taken only very few times and also we have 44 no of unique paths so lets combine the minority paths into a other group

# %%
def combine_paths(data,path_col):
    # getting the top 10 paths 
    top_10_paths = data['user_path'].value_counts(ascending=False).head(10).index.to_list()
    # combining the minority paths
    data['user_path'] = data['user_path'].apply(lambda x:x if x in top_10_paths else "others"  )
    return data 

paths = combine_paths(paths,"user_path")

# %%
# counting the paths
paths["user_path"].value_counts()
# Out:
# user_path
# others                                                             67
# product_view-->read_reviews-->click_wishlist_page-->add_to_cart    29
# read_reviews-->click_wishlist_page-->add_to_cart                   28
# search-->product_view-->read_reviews-->add_to_cart                 25
# click_wishlist_page-->add_to_cart                                  24
# add_to_cart                                                        24
# read_reviews-->add_to_cart                                         11
# product_view-->read_reviews-->add_to_cart                           9
# search-->read_reviews-->click_wishlist_page-->add_to_cart           9
# read_reviews-->product_view-->click_wishlist_page-->add_to_cart     8
# search-->product_view-->click_wishlist_page-->add_to_cart           6
# Name: count, dtype: int64

# %% [markdown]
# #### Category/SubCategory level features

# %% [markdown]
# ##### 1. Cart to Purchase (Category)

# %%
# calculating the cart-to-purchase ratio for each categories
cart_to_purchase_ratio_category =  get_ratios(df,"Category","Action","add_to_cart","purchase").rename(columns={"add_to_cart_to_purchase_ratios":"cart_to_purchase_ratios_category"})
cart_to_purchase_ratio_category.head()
# Out:
#           Category  count_add_to_cart  count_purchase  \
# 0      Accessories                 15            12.0
# 1  Air Conditioner                  1             2.0
# 2       Appliances                  1             1.0
# 3          Artwork                  1             0.0
# 4            Audio                  1             0.0
#
#    cart_to_purchase_ratios_category
# 0                               0.8
# 1                               2.0
# 2                               1.0
# 3                               0.0
# 4                               0.0

# %% [markdown]
# ##### 2. Cart to Purchase (SubCategory)

# %%
# calculating the cart-to-purchase ratio for each categories
cart_to_purchase_ratio_subcategory =  get_ratios(df,"SubCategory","Action","add_to_cart","purchase").rename(columns={"add_to_cart_to_purchase_ratios":"cart_to_purchase_ratios_subcategory"})
cart_to_purchase_ratio_subcategory.head()
# Out:
#            SubCategory  count_add_to_cart  count_purchase  \
# 0  Air Tight Container                  1             0.0
# 1          Air coolers                  1             1.0
# 2         Amazon Alexa                  1             0.0
# 3            Amplifier                  1             1.0
# 4       Audio Speakers                  1             0.0
#
#    cart_to_purchase_ratios_subcategory
# 0                                  0.0
# 1                                  1.0
# 2                                  0.0
# 3                                  1.0
# 4                                  0.0

# %% [markdown]
# ##### 3. Wishlist to Purchase (Category)

# %%
# calculating the cart-to-purchase ratio for each categories
wishlist_to_purchase_ratio_category =  get_ratios(df,"Category","Action","add_to_wishlist","purchase").rename(columns={"add_to_wishlist_to_purchase_ratios":"wishlist_to_purchase_ratios_category"})
wishlist_to_purchase_ratio_category.head()
# Out:
#              Category  count_add_to_wishlist  count_purchase  \
# 0         Accessories                      3              12
# 1           Baby Care                      1               1
# 2            Bed room                      1               5
# 3  Digital Appliances                      1               2
# 4     Digital Devices                      5               7
#
#    wishlist_to_purchase_ratios_category
# 0                                   4.0
# 1                                   1.0
# 2                                   5.0
# 3                                   2.0
# 4                                   1.4

# %% [markdown]
# ##### 4. Wishlist to Purchase (SubCategory)

# %%
# calculating the cart-to-purchase ratio for each categories
wishlist_to_purchase_ratio_subcategory =  get_ratios(df,"SubCategory","Action","add_to_wishlist","purchase").rename(columns={"add_to_wishlist_to_purchase_ratios":"wishlist_to_purchase_ratios_subcategory"})
wishlist_to_purchase_ratio_subcategory.head()
# Out:
#      SubCategory  count_add_to_wishlist  count_purchase  \
# 0          Books                      2               4
# 1    Bp monitors                      1               1
# 2        Bumpers                      1               1
# 3          Cases                      3               2
# 4  Charging wire                      1               3
#
#    wishlist_to_purchase_ratios_subcategory
# 0                                 2.000000
# 1                                 1.000000
# 2                                 1.000000
# 3                                 0.666667
# 4                                 3.000000

# %% [markdown]
# ##### 5. Click Wishlist to Purchase (Category)

# %%
# calculating the cart-to-purchase ratio for each categories
click_wishlist_to_purchase_ratio_category =  get_ratios(df,"Category","Action","click_wishlist_page","purchase").rename(columns={"click_wishlist_page_to_purchase_ratios":"click_wishlist_to_purchase_ratios_category"})
wishlist_to_purchase_ratio_subcategory.head()
click_wishlist_to_purchase_ratio_category.head()
# Out:
#       Category  count_click_wishlist_page  count_purchase  \
# 0  Accessories                         14            12.0
# 1   Appliances                          3             1.0
# 2      Artwork                          1             0.0
# 3        Audio                          1             0.0
# 4    Baby Care                          4             1.0
#
#    click_wishlist_to_purchase_ratios_category
# 0                                    0.857143
# 1                                    0.333333
# 2                                    0.000000
# 3                                    0.000000
# 4                                    0.250000

# %% [markdown]
# ##### 6. Click Wishlist to Purchase (SubCategory)

# %%
# calculating the cart-to-purchase ratio for each subcategories
click_wishlist_to_purchase_ratio_subcategory =  get_ratios(df,"SubCategory","Action","click_wishlist_page","purchase").rename(columns={"click_wishlist_page_to_purchase_ratios":"click_wishlist_to_purchase_ratios_subcategory"})
click_wishlist_to_purchase_ratio_subcategory.head()
# Out:
#            SubCategory  count_click_wishlist_page  count_purchase  \
# 0  Air Tight Container                          1             0.0
# 1          Air coolers                          1             1.0
# 2         Amazon Alexa                          1             0.0
# 3       Audio Speakers                          1             0.0
# 4         Baby Shampoo                          1             0.0
#
#    click_wishlist_to_purchase_ratios_subcategory
# 0                                            0.0
# 1                                            1.0
# 2                                            0.0
# 3                                            0.0
# 4                                            0.0

# %% [markdown]
# ##### 7. View to Purchase (Category)

# %%
# calculating the cart-to-purchase ratio for each subcategories
view_to_purchase_ratio_category =  get_ratios(df,"Category","Action","product_view","purchase").rename(columns={"product_view_to_purchase_ratios":"product_view_to_purchase_ratios_category"})
view_to_purchase_ratio_category.head()
# Out:
#           Category  count_product_view  count_purchase  \
# 0      Accessories                   9            12.0
# 1  Air Conditioner                   7             2.0
# 2          Artwork                   1             0.0
# 3            Audio                   1             0.0
# 4        Baby Care                   3             1.0
#
#    product_view_to_purchase_ratios_category
# 0                                  1.333333
# 1                                  0.285714
# 2                                  0.000000
# 3                                  0.000000
# 4                                  0.333333

# %% [markdown]
# ##### 8. View to Purchase (SubCategory)

# %%
# calculating the cart-to-purchase ratio for each subcategories
view_to_purchase_ratio_subcategory =  get_ratios(df,"SubCategory","Action","product_view","purchase").rename(columns={"product_view_to_purchase_ratios":"product_view_to_purchase_ratios_subcategory"})
view_to_purchase_ratio_subcategory.head()
# Out:
#        SubCategory  count_product_view  count_purchase  \
# 0     Amazon Alexa                   1             0.0
# 1       Arm sleeve                   1             0.0
# 2        Aux Cable                   3             1.0
# 3     Baby Shampoo                   1             0.0
# 4  Baby Shower gel                   1             0.0
#
#    product_view_to_purchase_ratios_subcategory
# 0                                     0.000000
# 1                                     0.000000
# 2                                     0.333333
# 3                                     0.000000
# 4                                     0.000000

# %% [markdown]
# ### Dataset Modelling

# %% [markdown]
# ##### Getting the labels

# %%
# function to get the label for the row
def get_label(lst):
    
    if len(lst)==1: #it means the user only added_to_cart and haven't bought anything
        return 0
    # Convert strings to datetime objects
    cart_time = pd.to_datetime(lst[0])
    purchase_time = pd.to_datetime(lst[1])
    # Calculate time difference
    time_diff = purchase_time - cart_time
    # Define a timedelta representing 2 hours
    two_hours = pd.Timedelta(hours=2)
    # Check if the time difference is less than or equal to 2 hours
    if time_diff <= two_hours:
        return 1
    else:
        return 0



# function to get the dataset
def get_dataset(data):
    dff= data.copy()
    # filtering the data only for purchase and add_to_cart action
    data = dff[dff['Action'].isin(["purchase", "add_to_cart"])]
    data.sort_values(by=["User_id","DateTime"],inplace=True)

    # grouping rows using "User_id", "Category", "SubCategory" and creating the action list anf respective datetime list
    data_grouped = data.groupby(["User_id", "Category", "SubCategory"]).agg({
        "Action": list,
        "DateTime": lambda x: x.tolist()
    })
    data_grouped.reset_index(inplace=True)
    # filtering rows where add_to_cart action is followed by purchase action
    filtered_data = data_grouped[data_grouped['Action'].apply(lambda x: (x == ['add_to_cart', 'purchase']) or (x == ['add_to_cart'] ))]
    # getting the labels if the difference between the datetime elements in the list is less than 2 hrs
    filtered_data["Label"]=filtered_data["DateTime"].apply(get_label)

    # dropping the unwanted columns
    filtered_data.drop(columns=["Action","DateTime"],inplace=True)

    return filtered_data

# %%
# getting the dataset
df_base = get_dataset(df)

df_base
# Out:
#          User_id                Category             SubCategory  Label
# 0    51448162784      Camera Accessories              Camera Bag      1
# 1    51448162784      Camera Accessories             Camera Lens      0
# 2    51455512201           Men's Fashion                   Shoes      0
# 3    51462598385    Mobile & Accessories               Aux Cable      1
# 4    51462598385    Mobile & Accessories                USB Cord      0
# 6    51463622150              Stationary                  Paints      1
# 8    51465529647              Home Decor           Wall hangings      0
# 9    51468519074                   Gifts               Paintings      1
# 12   51480378215   Electronic Appliances              Microphone      0
# 14   51481443687     Gardern and Outdoor       Flower plant seed      0
# 15   51481443687     Gardern and Outdoor                    Pots      0
# 16   51486113570           Men's Fashion             Denim jeans      1
# 17   51508416101           Men's Fashion                   Socks      1
# 18   51512259423              Stationary                   Books      0
# 20   51517997197              Home Decor              Wall paint      1
# 21   51526464449      Digital Appliances                  Laptop      0
# 22   51526464449      Digital Appliances                 Monitor      0
# 23   51544071846              Stationary                   Books      0
# 24   51558926605                Software       McAfee Protection      1
# 25   51560282867                 Fitness                  Gloves      0
# 27   51565158157         Women's Fashion               Jewellery      1
# 29   51572478237        Large appliances       Digital air fryer      0
# 30   51574504569         Digital Devices             Memory Card      0
# 33   51589427926    Mobile & Accessories            Screen Guard      1
# 34   51592642763   Entertainment Systems                Speakers      1
# 35   51592642763   Entertainment Systems         Surround system      1
# 36   51596197877              Stationary                   Books      1
# 37   51596197877              Stationary                 Crayons      1
# 38   51597745082         Digital Devices            Flash drives      0
# 39   51607023962      Kitchen Appliances              Frying pan      0
# 40   51613167885    Mobile & Accessories                  Mobile      0
# 41   51616505593         Women's Fashion             Ethnic wear      0
# 42   51624877138              Appliances              Frying pan      1
# 43   51626168971         Digital Devices                  laptop      1
# 44   51629142904       Cleaning supplies         Cleaning sprays      0
# 45   51629142904    Mobile & Accessories           Charging wire      0
# 46   51632985791         Digital Devices                Printers      0
# 47   51633993644             Accessories              wrist band      0
# 48   51637676508      Gaming Accessories            Play station      1
# 49   51639618110         Digital Devices              Headphones      0
# 51   51649462163             Accessories                    Ring      0
# 52   51658664493   Motorbike Accessories                Tank pad      0
# 53   51676463689                Pet Care                Cat food      1
# 54   51676463689              Stationary                   Books      1
# 55   51677518852      Camera Accessories          Photo day pack      0
# 56   51692749291             Accessories               CD-Driver      1
# 57   51692946248         Women's Fashion                    Tops      1
# 58   51714485793                  Sports                Football      1
# 59   51720357111         Digital Devices           Digital clock      1
# 60   51723980162        Bags and Luggage                suitcase      1
# 61   51725305614                   Gifts         Gift containers      1
# 62   51725305614           Men's Fashion                  Shirts      0
# 63   51743891883           Men's Fashion                  Wallet      0
# 65   51768712908           Kid's fashion              kids jeans      0
# 67   51777661967      Camera Accessories                    Lens      0
# 68   51784286337         Digital Devices                Printers      0
# 69   51786146119    Mobile & Accessories                 Bumpers      0
# 70   51795247161         Digital Devices             Tws earbuds      1
# 71   51804424828         Digital Devices            Kindle eBook      0
# 72   51805850313         Women's Fashion               Ear rings      0
# 73   51809677865           Baby Products            Baby Shampoo      0
# 74   51821460103             Accessories                 Oil can      1
# 75   51826884161           Kid's fashion            Leather pant      0
# 77   51838622321         Women's Fashion           Shoulder Bags      0
# 78   51840127985         Car Accessories       Car Mobile holder      1
# 79   51840332148         Religious items            Photo frames      1
# 80   51849471720         Women's Fashion              Hair Bands      1
# 81   51859784960             Accessories                Bracelet      0
# 82   51863353060             Accessories          Harddisk cover      1
# 83   51871605199           Men's Fashion                  Shirts      0
# 84   51872149089   Electronic Appliances              Web camera      0
# 85   51875286469    Mobile & Accessories                 Charger      1
# 86   51876683702                    Toys             Squeeze toy      0
# 87   51883832383                 Fitness               Treadmill      0
# 88   51883832383       Tv and Appliances                      TV      0
# 89   51888851862                 Music\n                    Cd's      1
# 90   51892634497               Gardening         Gardening knife      1
# 91   51893446663    Mobile & Accessories        Skins for mobile      0
# 92   51895612143        Large appliances         Washing machine      1
# 94   51936108956         Air Conditioner    Split airconditioner      0
# 95   51940324591                 Fitness                Dumbells      0
# 96   51940324591    Mobile & Accessories                   Cases      0
# 97   51945183373             Accessories                 Watches      1
# 99   51962945277                    Toys      Remote control car      0
# 101  51968118114              Stationary                   Books      0
# 102  51969791374           Men's Fashion                   Jeans      1
# 103  51969791374         Women's Fashion                    Tops      0
# 104  51970999139      Camera Accessories                 Tripods      1
# 105  51978529551                   Music               Amplifier      1
# 106  51993965030           Men's Fashion                   Kadaa      1
# 107  52005335676    Mobile & Accessories           Tablet holder      1
# 108  52008466873      Camera Accessories                    Lens      0
# 109  52010733268      Camera Accessories                    Lens      0
# 110  52011317619         Digital Devices              Headphones      0
# 111  52028780773             Accessories                 Watches      0
# 112  52055074267         Home Appliances                    Lamp      1
# 113  52056666335                Footwear                   Shoes      0
# 114  52056666335        Large appliances          Microwave oven      0
# 115  52057059159         Digital Devices         Lightning cable      0
# 116  52066176372         Religious items               Pooja kit      0
# 117  52090547553         Car Accessories             Car charger      1
# 118  52094145973    Mobile & Accessories           Charging wire      1
# 119  52112239597              Furnitures                    Sofa      1
# 120  52114046370      Gaming Accessories          Gaming console      1
# 121  52127053360    Mobile & Accessories          Mobile Battery      1
# 122  52131345840              Industrial     Scientific products      0
# 123  52132350231             Accessories                Harddisk      1
# 124  52146571882                    Toys             Rubber toys      1
# 125  52157383130                   Gifts             Handicrafts      1
# 126  52157553629         Women's Fashion              Makeup kit      0
# 128  52164722572           Kid's fashion         Kids sunglasses      0
# 129  52165465642   Entertainment Systems          Audio Speakers      0
# 130  52169959151         Digital Devices              Headphones      0
# 131  52176580407         Digital Content                   eBook      0
# 132  52178524942                 Fitness               Dumbbells      1
# 134  52183942377         Women's Fashion          Ethinc dresses      1
# 135  52195970192              Stationary                   Books      0
# 137  52202543340         Home Appliances            Home theater      0
# 138  52205716885             Accessories               Bracelets      0
# 139  52205716885                    Toys             Squeeze toy      0
# 140  52206085693              Stationary                   Books      0
# 141  52222290151              Stationary               Pen stand      0
# 143  52246240339                Software        McAfee antivirus      1
# 144  52260620086      Camera Accessories                 Monopod      0
# 145  52284554941                 Fitness                yoga mat      0
# 146  52304321020         Personal Safety  Fire extinguisher mini      1
# 148  52313781035           Men's Fashion                 Bow tie      1
# 149  52316857999      Camera Accessories           Camera slider      0
# 150  52320144114         Digital Devices     Wireless Headphones      1
# 151  52322653716           Men's Fashion                    Belt      1
# 153  52335257008    Mobile & Accessories           Charging wire      1
# 154  52340757893   Electronic Appliances                Speakers      0
# 155  52340778300         Women's Fashion                    Tops      1
# 156  52387379385           Home lighting             Smart light      1
# 157  52627455489             Electronics        Electrical wires      1
# 158  52713090310                Bed room               Wardrobes      1
# 159  52730728074                   Audio                Soundbar      0
# 160  52732772360      Laptop Accessories              Data cards      1
# 162  52766692567          Men's Top Wear            Formal shirt      0
# 163  52769802843               Baby Care                 Diapers      0
# 164  52769802843                    Toys                 Toy car      1
# 165  52787855576                 Tablets                    iPad      0
# 166  52805483647                    Kids             Infant wear      0
# 167  52842945535             Accessories                  Frames      1
# 168  52904721877      Mobile accessories          Mini powerbank      1
# 169  52942481269                    Toys                 Puzzles      0
# 170  53066213242       Men's Bottom Wear                  Pyjama      0
# 171  53156872654                 Laptops               Notebooks      1
# 172  53209756433                Footwear                   Crocs      1
# 173  53209756433           Women Fashion                   Jeans      0
# 174  53209947945           Personal Care                epilator      1
# 175  53277489525              Home Decor            Wall shelves      0
# 176  53299207031                   Books             Non fiction      1
# 178  53561530361   Smart Home Automation          Smart switches      0
# 179  53572384601           Women Fashion              Party wear      1
# 181  53617353246      Kitchen and dining              Dinner set      1
# 182  53649822812                 Fitness                   Ropes      1
# 183  53649822812                  Health  Blood pressure monitor      0
# 184  53652969521      Laptop and Desktop           Gaming laptop      1
# 185  53654005940       Lock and Security               Door lock      1
# 186  53660108929        Large appliances                Chimneys      0
# 187  53713888319         Women's Fashion                Palazzos      1
# 188  53966220604               Bike care             Bike polish      1
# 190  53988566659      Sports Accessories           Swimming Fins      0
# 191  54068495712      Laptop Accessories          Laptop charger      1
# 192  54074421036   Smart Home Automation            Smart lights      0
# 193  54081180520         Food essentials              Chocolates      1
# 194  54144005834         Religious items                  Candle      0
# 195  54160504190              Home Decor            flower vases      1
# 196  54187466030           Kid's fashion              Kids shirt      0
# 197  54211903284                 Grocery             Refined oil      0
# 198  54340210344       Men's Bottom Wear                 Cargo's      1
# 199  54442238798                Software             K7 security      1
# 200  54447852002                    Toys             Barbie doll      1
# 201  54447852002                    Toys                Toy guns      1
# 202  54500871579           Women western               Nightsuit      0
# 203  54615021891            Pet Supplies                Cat food      0
# 205  54654196217   Motorbike Accessories               Rear lamp      0
# 206  54938485256             Electronics          Weighing scale      1
# 207  55025507925         Food essentials          Oil containers      1
# 208  55025507925            Pet Supplies                Cat food      1
# 209  55162718788         Kitchen Storage              Containers      1
# 210  55237981670              Stationary                 Diaries      1
# 211  55343474855                Bed room                  Sheets      1
# 212  55343474855                Bed room              Side table      1
# 213  55349718167                   Books             Non fiction      0
# 214  55349718167              Stationary                 Markers      1
# 215  55387472465      Kitchen and dining               Glassware      0
# 217  55488853063                   Gifts         Paintings small      0
# 218  55488853063                 Grocery              Flour Bags      1
# 220  55616110021             Living room                   Lamps      0
# 221  55660418761             Electronics          Ink cartridges      0
# 222  55660418761                 Fitness              Boxing Bag      1
# 223  55747248896     Musical Instruments                Keyboard      0
# 224  55795626852     Musical Instruments           Violin string      1
# 225  55817701891       Tv and Appliances                      TV      1
# 226  56016671367                 Storage      External harddrive      1
# 228  56286709029         Car Accessories            Car freshner      0
# 230  56295462878     Gardern and Outdoor            Watering can      0
# 231  56348505101         Smart Wearables           Smart watches      1
# 232  56478374077               Shoe care             Shoe polish      0
# 233  56567774661               Baby Care              Baby wipes      0
# 234  56649710141          Women Footwear              High heels      0
# 235  56734081898             Accessories            Contact lens      1
# 236  56924254686               Baby Care           Baby care set      0
# 238  57181419152        Bags and Luggage               Sling bag      1
# 239  57190679381             Living room           Office tables      0
# 240  57253954514       Tools and Utility      Multiutility plier      1
# 242  57326081828    Computer Peripherals     Portable projectors      1
# 244  57354053843      Camera Accessories                 Gimbles      0
# 245  57467662502        Electrical tools     Measurement devices      0
# 246  57500609913    Mobile & Accessories            Mobile phone      1
# 247  57507062720                 Artwork        Handcrafted idol      0
# 248  57510470450          Men's Top Wear                  Blazer      0
# 249  57515591429   Smart Home Appliances         Smart door lock      0
# 250  57574752442         Home Appliances          vaccum cleaner      1
# 251  57767840151      Kitchen Appliances            Wet grinders      0
# 252  57767840151              Stationary                    Pens      1
# 253  57828063559                    Toys              Teddy Bear      1
# 254  57828063559               eCommerce      Travell Bags Large      0
# 255  57841579837    Mobile & Accessories          Mobile Holders      0
# 256  57851680477                 Grocery             Cooking oil      1
# 257  57851680477       Lock and Security               Door lock      0
# 258  57915402788           Baby Products                   wipes      1
# 259  57924356302           Home lighting              Table lamp      0
# 260  58023540073   Smart Home Automation            Amazon Alexa      0
# 261  58041962869         Car Accessories               Car cover      0
# 262  58055328154        Mens accessories                Perfumes      1
# 263  58078346967      Kitchen Appliances          Toaster Grills      0
# 264  58113870922           Women Fashion                   Kurti      1
# 265  58231974593             Accessories              Binoculars      0
# 266  58481913506                   Gifts           Gift wrappers      1
# 267  58481913506                 Tablets                    iPad      1
# 268  58559504289         Home Appliances          Vaccum cleaner      1
# 269  58624247783             Winter Wear             Sweatshirts      0
# 270  58653489700                   Books            Crime novels      1
# 271  58696564595              Home Decor              Showpieces      0
# 272  58749258284   Living Room Furniture         Wooden sofa set      1
# 273  58835668300         Kitchen Storage     Air Tight Container      0
# 274  58974674178                Footwear                 sandals      1
# 275  59075844984     Musical Instruments             Guitar case      0
# 276  59151802235    Computer Peripherals        Barcode scanners      0
# 278  59275285732   Entertainment Systems         Surround system      1
# 279  59294392552            Pet Supplies               Dog chain      0
# 280  59497643754     Gardern and Outdoor         Garden tool set      0
# 281  59526755891         Home furnishing        Bathroom Fitings      1
# 282  59533420690             Electricals               Batteries      1
# 283  59533420690  Health care appliances             Bp monitors      1
# 284  59589745593          Men's Grooming               Beard Oil      1
# 285  59602347302         Home furnishing                Blankets      0
# 286  59629862188         School Supplies             School bags      1
# 287  59713929100     Seasonal Appliances             Air coolers      1
# 288  59718871437           Personal Care                 Trimmer      0
# 289  59737632719                  Camera                    DSLR      1
# 290  59839573750        Mens accessories              Sunglasses      1
# 291  59916849754         Kitchen Storage               Lunch box      1
# 293  60034334067             Accessories                 Watches      1
# 294  60089394505   Living Room Furniture                TV shelf      1
# 295  60238282834                 Fitness                   Ropes      1
# 296  60238282834                 Fitness           Shaker bottle      1
# 297  60238282834           Personal Care              Sunscreens      1
# 298  60300257008                Pet Care              Puppy food      0
# 299  60302643179             Accessories                 Watches      0
# 300  60302643179                    Toys             Puzzle play      1

# %% [markdown]
# #### Testin ends

# %%
# adding no of days active feature
df_base = pd.merge(df_base,days_active,on="User_id",how="left")
df_base.head()
# Out:
#        User_id              Category  SubCategory  Label  days_active
# 0  51448162784    Camera Accessories   Camera Bag      1            3
# 1  51448162784    Camera Accessories  Camera Lens      0            3
# 2  51455512201         Men's Fashion        Shoes      0            3
# 3  51462598385  Mobile & Accessories    Aux Cable      1            5
# 4  51462598385  Mobile & Accessories     USB Cord      0            5

# %%
# adding RFM features for the users
users_rfm_features = df.groupby("User_id").agg({"R":"max","F":"max","M":"max","Loyalty":"max"})
df_base = pd.merge(df_base,users_rfm_features,on="User_id",how="left")
df_base.head()
# Out:
#        User_id              Category  SubCategory  Label  days_active    R  \
# 0  51448162784    Camera Accessories   Camera Bag      1            3  4.0
# 1  51448162784    Camera Accessories  Camera Lens      0            3  4.0
# 2  51455512201         Men's Fashion        Shoes      0            3  3.0
# 3  51462598385  Mobile & Accessories    Aux Cable      1            5  4.0
# 4  51462598385  Mobile & Accessories     USB Cord      0            5  4.0
#
#      F    M   Loyalty
# 0  4.0  4.0  Platinum
# 1  4.0  4.0  Platinum
# 2  1.0  3.0      Gold
# 3  4.0  1.0  Platinum
# 4  4.0  1.0  Platinum

# %%
# adding avg_time between purchase
df_base = pd.merge(df_base,avg_purchase_time[["User_id","Avg Purchase Gap"]],on="User_id",how="left")
df_base.head()
# Out:
#        User_id              Category  SubCategory  Label  days_active    R  \
# 0  51448162784    Camera Accessories   Camera Bag      1            3  4.0
# 1  51448162784    Camera Accessories  Camera Lens      0            3  4.0
# 2  51455512201         Men's Fashion        Shoes      0            3  3.0
# 3  51462598385  Mobile & Accessories    Aux Cable      1            5  4.0
# 4  51462598385  Mobile & Accessories     USB Cord      0            5  4.0
#
#      F    M   Loyalty  Avg Purchase Gap
# 0  4.0  4.0  Platinum             184.0
# 1  4.0  4.0  Platinum             184.0
# 2  1.0  3.0      Gold               NaN
# 3  4.0  1.0  Platinum              56.0
# 4  4.0  1.0  Platinum              56.0

# %%
# adding the carts_to_purchase ratios for each user
df_base = pd.merge(df_base,cart_to_purchase[["User_id","add_to_cart_to_purchase_ratios"]],on="User_id",how="left")
df_base.head()
# Out:
#        User_id              Category  SubCategory  Label  days_active    R  \
# 0  51448162784    Camera Accessories   Camera Bag      1            3  4.0
# 1  51448162784    Camera Accessories  Camera Lens      0            3  4.0
# 2  51455512201         Men's Fashion        Shoes      0            3  3.0
# 3  51462598385  Mobile & Accessories    Aux Cable      1            5  4.0
# 4  51462598385  Mobile & Accessories     USB Cord      0            5  4.0
#
#      F    M   Loyalty  Avg Purchase Gap  add_to_cart_to_purchase_ratios
# 0  4.0  4.0  Platinum             184.0                             1.0
# 1  4.0  4.0  Platinum             184.0                             1.0
# 2  1.0  3.0      Gold               NaN                             1.0
# 3  4.0  1.0  Platinum              56.0                             1.0
# 4  4.0  1.0  Platinum              56.0                             1.0

# %%
# adding the wishlist_to_purchase ratios for each user
df_base = pd.merge(df_base,wishlist_to_purchase[["User_id","add_to_wishlist_to_purchase_ratios"]],on="User_id",how="left")
df_base.head()
# Out:
#        User_id              Category  SubCategory  Label  days_active    R  \
# 0  51448162784    Camera Accessories   Camera Bag      1            3  4.0
# 1  51448162784    Camera Accessories  Camera Lens      0            3  4.0
# 2  51455512201         Men's Fashion        Shoes      0            3  3.0
# 3  51462598385  Mobile & Accessories    Aux Cable      1            5  4.0
# 4  51462598385  Mobile & Accessories     USB Cord      0            5  4.0
#
#      F    M   Loyalty  Avg Purchase Gap  add_to_cart_to_purchase_ratios  \
# 0  4.0  4.0  Platinum             184.0                             1.0
# 1  4.0  4.0  Platinum             184.0                             1.0
# 2  1.0  3.0      Gold               NaN                             1.0
# 3  4.0  1.0  Platinum              56.0                             1.0
# 4  4.0  1.0  Platinum              56.0                             1.0
#
#    add_to_wishlist_to_purchase_ratios
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN

# %%
# adding the click_wishlist_to_purchase ratios for each user
df_base = pd.merge(df_base,wishlist_click_to_purchase[["User_id","click_wishlist_page_to_purchase_ratios"]],on="User_id",how="left")
df_base.head()
# Out:
#        User_id              Category  SubCategory  Label  days_active    R  \
# 0  51448162784    Camera Accessories   Camera Bag      1            3  4.0
# 1  51448162784    Camera Accessories  Camera Lens      0            3  4.0
# 2  51455512201         Men's Fashion        Shoes      0            3  3.0
# 3  51462598385  Mobile & Accessories    Aux Cable      1            5  4.0
# 4  51462598385  Mobile & Accessories     USB Cord      0            5  4.0
#
#      F    M   Loyalty  Avg Purchase Gap  add_to_cart_to_purchase_ratios  \
# 0  4.0  4.0  Platinum             184.0                             1.0
# 1  4.0  4.0  Platinum             184.0                             1.0
# 2  1.0  3.0      Gold               NaN                             1.0
# 3  4.0  1.0  Platinum              56.0                             1.0
# 4  4.0  1.0  Platinum              56.0                             1.0
#
#    add_to_wishlist_to_purchase_ratios  click_wishlist_page_to_purchase_ratios
# 0                                 NaN                                     2.0
# 1                                 NaN                                     2.0
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN

# %%
# adding the latest path for each user
df_base = pd.merge(df_base,paths,on="User_id",how="left")
df_base.head()
# Out:
#        User_id              Category  SubCategory  Label  days_active    R  \
# 0  51448162784    Camera Accessories   Camera Bag      1            3  4.0
# 1  51448162784    Camera Accessories  Camera Lens      0            3  4.0
# 2  51455512201         Men's Fashion        Shoes      0            3  3.0
# 3  51462598385  Mobile & Accessories    Aux Cable      1            5  4.0
# 4  51462598385  Mobile & Accessories     USB Cord      0            5  4.0
#
#      F    M   Loyalty  Avg Purchase Gap  add_to_cart_to_purchase_ratios  \
# 0  4.0  4.0  Platinum             184.0                             1.0
# 1  4.0  4.0  Platinum             184.0                             1.0
# 2  1.0  3.0      Gold               NaN                             1.0
# 3  4.0  1.0  Platinum              56.0                             1.0
# 4  4.0  1.0  Platinum              56.0                             1.0
#
#    add_to_wishlist_to_purchase_ratios  click_wishlist_page_to_purchase_ratios  \
# 0                                 NaN                                     2.0
# 1                                 NaN                                     2.0
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#                                             user_path
# 0                                              others
# 1                                              others
# 2  search-->product_view-->read_reviews-->add_to_cart
# 3  search-->product_view-->read_reviews-->add_to_cart
# 4  search-->product_view-->read_reviews-->add_to_cart

# %%
# adding category and sub-category level features carts_to_purchase ratios
df_base = pd.merge(df_base,cart_to_purchase_ratio_category[["Category","cart_to_purchase_ratios_category"]],on="Category",how="left")
df_base = pd.merge(df_base,cart_to_purchase_ratio_subcategory[["SubCategory","cart_to_purchase_ratios_subcategory"]],on="SubCategory",how="left")

# %%
# adding category and sub-category level features wishlist_to_purchase ratios
df_base = pd.merge(df_base,wishlist_to_purchase_ratio_category[["Category","wishlist_to_purchase_ratios_category"]],on="Category",how="left")
df_base = pd.merge(df_base,wishlist_to_purchase_ratio_subcategory[["SubCategory","wishlist_to_purchase_ratios_subcategory"]],on="SubCategory",how="left")

# %%
# adding category and sub-category level features click_wishlist_to_purchase ratios
df_base = pd.merge(df_base,click_wishlist_to_purchase_ratio_category[["Category","click_wishlist_to_purchase_ratios_category"]],on="Category",how="left")
df_base = pd.merge(df_base,click_wishlist_to_purchase_ratio_subcategory[["SubCategory","click_wishlist_to_purchase_ratios_subcategory"]],on="SubCategory",how="left")

# %%
# adding category and sub-category level features view_to_purchase ratios
df_base = pd.merge(df_base,view_to_purchase_ratio_category[["Category","product_view_to_purchase_ratios_category"]],on="Category",how="left")
df_base = pd.merge(df_base,view_to_purchase_ratio_subcategory[["SubCategory","product_view_to_purchase_ratios_subcategory"]],on="SubCategory",how="left")

# %%
# dropping the user_id column
df_base.drop(columns=["User_id"],inplace=True)

# %%
df_base.head()
# Out:
#                Category  SubCategory  Label  days_active    R    F    M  \
# 0    Camera Accessories   Camera Bag      1            3  4.0  4.0  4.0
# 1    Camera Accessories  Camera Lens      0            3  4.0  4.0  4.0
# 2         Men's Fashion        Shoes      0            3  3.0  1.0  3.0
# 3  Mobile & Accessories    Aux Cable      1            5  4.0  4.0  1.0
# 4  Mobile & Accessories     USB Cord      0            5  4.0  4.0  1.0
#
#     Loyalty  Avg Purchase Gap  add_to_cart_to_purchase_ratios  \
# 0  Platinum             184.0                             1.0
# 1  Platinum             184.0                             1.0
# 2      Gold               NaN                             1.0
# 3  Platinum              56.0                             1.0
# 4  Platinum              56.0                             1.0
#
#    add_to_wishlist_to_purchase_ratios  click_wishlist_page_to_purchase_ratios  \
# 0                                 NaN                                     2.0
# 1                                 NaN                                     2.0
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#                                             user_path  \
# 0                                              others
# 1                                              others
# 2  search-->product_view-->read_reviews-->add_to_cart
# 3  search-->product_view-->read_reviews-->add_to_cart
# 4  search-->product_view-->read_reviews-->add_to_cart
#
#    cart_to_purchase_ratios_category  cart_to_purchase_ratios_subcategory  \
# 0                          0.300000                                  1.0
# 1                          0.300000                                  1.0
# 2                          0.800000                                  1.0
# 3                          0.933333                                  1.0
# 4                          0.933333                                  1.0
#
#    wishlist_to_purchase_ratios_category  \
# 0                                   NaN
# 1                                   NaN
# 2                              8.000000
# 3                              2.333333
# 4                              2.333333
#
#    wishlist_to_purchase_ratios_subcategory  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    click_wishlist_to_purchase_ratios_category  \
# 0                                        0.30
# 1                                        0.30
# 2                                        2.00
# 3                                        1.75
# 4                                        1.75
#
#    click_wishlist_to_purchase_ratios_subcategory  \
# 0                                            1.0
# 1                                            NaN
# 2                                            1.0
# 3                                            NaN
# 4                                            NaN
#
#    product_view_to_purchase_ratios_category  \
# 0                                  0.600000
# 1                                  0.600000
# 2                                  0.615385
# 3                                  0.538462
# 4                                  0.538462
#
#    product_view_to_purchase_ratios_subcategory
# 0                                          NaN
# 1                                     1.000000
# 2                                     0.500000
# 3                                     0.333333
# 4                                     1.000000

# %%
# exporting the data
df_base.to_csv("data/customer_data_engineered_features.csv",index=False)
